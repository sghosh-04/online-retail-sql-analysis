# %%
import pandas as pd

fact = pd.read_csv("../data/processed/FactFinancialIndicators.csv")

# %%
from sqlalchemy import create_engine

engine = create_engine(
    r"mssql+pyodbc://localhost\SQLEXPRESS/EnterpriseBI?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

with engine.connect() as conn:
    print("Connected successfully!")
# Out:
# Connected successfully!

# %%
fact.to_sql(
    "FactFinancialIndicators",
    engine,
    schema="warehouse",
    if_exists="replace",
    index=False
)
# Out:
# 1
